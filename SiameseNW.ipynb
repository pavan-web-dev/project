# %% [markdown]
# # Import Libraries

# %%
# Import the necessary python libraries.
import tensorflow as tf
import numpy as np
import random

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Activation,AveragePooling2D
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import backend as K

import os
from tqdm import tqdm
from PIL import Image

import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 128

# %% [markdown]
# ![Image Preparation.png](data:image/png;base64,...)

# %% [markdown]
# # Prepare Data

# %%
class Data_Prep():
  '''
  Class that prepares the custom input data for the neural network.
  '''

  def __init__(self, seed = 77, img_size = 128, data_dir = '/content/drive/MyDrive/data_folder', sample_size = 2000):
    '''
    Init Data_Prep

    Args:
      seed::[int]
      Set the seed for reproducibility of code. Default: 77.

      img_size::[int]
      Input image dimension. Default: 128.

      data_dir::[str]
      Directory that contains the data.

      sample_size::[int]
      The number of samples for training set. 
      Limit is the max number of training images. Default: 2000
    '''
    self.data_dir = data_dir

    # Best practice, for random number generator seed settings.
    self.rng = np.random.default_rng(seed)

    self.img_size = img_size

    self.sample_size = sample_size


  def read_image_array(self, sub_dir, sample_size = None, shuffle = False):
    '''
    Read the images from directory.

    Args:
      
      sub_dir::[str]
      Name of the sub folder within base directory that contains the 
      the images.

      sample_size::[int]
      Number of images to read.

      shuffle::[bool]
      Param to indicate shuffling of data.

    Return::[np.array]:
      Return numpy array of all images.

    '''
    # The full path
    full_path = os.path.join(self.data_dir, sub_dir)
    
    # The image file names at path
    image_list = os.listdir(full_path)

    # Number of total images in image list
    n_img = len(image_list)

    # Whether to shuffle the data.
    if shuffle:
      
      self.rng.shuffle(image_list)

    if sample_size:

      # restrict the sample size to be smaller than the number
      # of images in image_list. 
      if sample_size > n_img:

        raise('Cannot sample images more than the number in set')

      # Select a smaller sample.
      image_list = image_list[:sample_size]

    # Store result in this list.
    image_read_res = []

    print(f'Starting to read {sub_dir} images')

    # For loop to read the images, and resizing them in the process.
    for i in tqdm(image_list):
      
      image_read_res.append(np.asarray(Image.open(f"{full_path}/{i}").resize((self.img_size, self.img_size), Image.ANTIALIAS)))

    # Return numpy array
    return np.array(image_read_res)

  def read_data(self):
    '''
    Driver code to read in input images from multiple source.

    Args:
      None
    
    Returns:
      None
    '''

    # Category 1 images that contain mantaray images.
    image_1 = self.read_image_array('train2020', self.sample_size, True)

    # Category 0 images that contain segmentated background images.
    image_0_tl = self.read_image_array('top_left', self.sample_size // 4, True)
    image_0_tr = self.read_image_array('top_right', self.sample_size // 4, True)
    image_0_bl = self.read_image_array('bottom_left', self.sample_size // 4, True)
    image_0_br = self.read_image_array('bottom_right', self.sample_size // 4, True)

    # Bring together the four corners.
    image_0 = np.concatenate([image_0_tl, image_0_tr, image_0_bl, image_0_br], axis=0)

    # Useful info.
    print(f'Image category 1 shape {image_1.shape} & size {(image_1.size * image_1.itemsize) / 1000000} MB')

    print(f'Image category 0 shape {image_0.shape} & size {(image_0.size * image_0.itemsize) / 1000000} MB')

    # Both category images together form the training set.
    X_train = np.concatenate([image_0, image_1], axis=0)

    # Create category label.
    y_train = [0] * image_0.shape[0] + [1] * image_1.shape[0]

    # Normalize the image values.
    X_train = X_train / 255

    # Covert to float32
    X_train = X_train.astype('float32')

    # Useful info
    print(f'X_train shape {X_train.shape} & size {(X_train.size * X_train.itemsize) / 1000000} MB')
    print(f'y_train shape {len(y_train)}')

    # Raise error if the shape is not the same.
    assert len(X_train) == len(y_train)

    # Shuffle the data in pairs.
    p = self.rng.permutation(len(X_train))

    # X_train, y_train
    self.X_train, self.y_train = X_train[p], np.array(y_train)[p]

    # Set the number of classes
    self.num_classes = len(np.unique(y_train))
    

  def create_pairs(self, x, class_indices):
    '''
    Function that creates Siamese network input pairs and labels. Here the 
    objective is to create matching pairs marked as label 1 and non-matching 
    pairs marked as label 0.

    Args:
      x::[np.array]
      The image numpy array data.
      
      class_indices::[np.array]
      An array containing an array for each category, indicating the image
      position within array.

    Returns:
      Pairs and labels.
    '''

    print('Started creating pairs ...')

    # Training pairs
    training_pairs = []
    
    # Labels. If same class image then 1, or else 0.
    labels = []

    # Since, each category has variable images, take the minimum to avoid
    # list range problem.
    n = min( [len(class_indices[c]) for c in range(self.num_classes)] ) - 1

    # For each class
    for d in range(self.num_classes):

      # For each sample
      for i in range(n):

        # Form pairs with current and next image in same class.
        i1, i2 = class_indices[d][i], class_indices[d][i+1]
        
        # Add this image pair to training set.
        training_pairs += [[x[i1], x[i2]]]
        
        # Randomly add a number from 1 to num_class to current class.
        # Shift the base as class starts with 0.
        inc = random.randrange(1, self.num_classes)
        dn = (d + inc) % self.num_classes

        # Add training pair from different classes.
        # That is our class 0.
        i1, i2 = class_indices[d][i], class_indices[dn][i]
        training_pairs += [[x[i1], x[i2]]]

        # Add labels
        labels += [1,0]

    print('Finished creating pairs & labels. :)')
        
    return np.array(training_pairs), np.array(labels)

  def __call__(self):
    '''
    Main driver code to call all the above functions to read in training data.

    Returns:
      Training pairs and labels.
    '''
    self.read_data()

    self.digit_indices = [np.where(self.y_train == i)[0] for i in range(self.num_classes)]

    return self.create_pairs(self.X_train, self.digit_indices)

# %%
dpin = Data_Prep(img_size = IMAGE_SIZE, sample_size=1200)

# %%
dp_output = dpin()
# Out:
# Starting to read train2020 images
# 100%|██████████| 1200/1200 [02:07<00:00,  9.39it/s]
# Starting to read top_left images
# 100%|██████████| 300/300 [00:31<00:00,  9.54it/s]
# Starting to read top_right images
# 100%|██████████| 300/300 [00:37<00:00,  8.09it/s]
# Starting to read bottom_left images
# 100%|██████████| 300/300 [00:37<00:00,  8.07it/s]
# Starting to read bottom_right images
# 100%|██████████| 300/300 [00:35<00:00,  8.53it/s]
# Image category 1 shape (1200, 128, 128, 3) & size 58.9824 MB
# Image category 0 shape (1200, 128, 128, 3) & size 58.9824 MB
# X_train shape (2400, 128, 128, 3) & size 471.8592 MB
# y_train shape 2400
# Started creating pairs ...
# Finished creating pairs & labels. :)

# %% [markdown]
# ## Siamese Network Architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Custom Loss Function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Implementation of the Contrastive Loss.
# Theory Explanation.
# http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf

from tensorflow import keras
class CustomCL(keras.losses.Loss):
  def __init__(self, margin = 1, name="custom_cl"):
    super().__init__(name=name)

    # Margin is the hyperparameter.
    self.margin = margin

  def call(self, y_true, y_pred):
    
    # Convert from int to float.
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)

    # Apply the formula.
    d_w2 = K.square(y_pred)
    margin_d_w2 = K.square(K.maximum(self.margin - y_pred, 0))
    total_loss =  K.mean(y_true * d_w2 + (1 - y_true) * margin_d_w2)
    return total_loss

# %%
def compute_acc(y_true, y_pred):
  '''Compute classification accuracy with a fixed threshold on distances.
  '''
  pred = y_pred.ravel() < 0.5
  return np.mean(pred == y_true)

# %%
def custom_acc(y_true, y_pred):

    # Binarize the prediction into class 1 or 0.
    bin_class = K.cast(y_pred < 0.5, y_true.dtype)
    
    # Check if pred = true. 1 for yes, 0 for no.
    check_eq = K.equal(y_true, bin_class)

    # Return number of correctly predicted cases as accuracy
    return K.mean(check_eq)

# %% [markdown]
# # Siamese Network Builder

# %%
class Siamese_Model():
  '''
  Build the Siamese Model.
  '''
  def __init__(self, num_classes = 2, input_shape = (128, 128, 3)):
    ''' 
    Initialize the model.

    Args:
      num_classes::[int]
      Number of unique categories. 

      input_shape::[tuple]
      Input Image Shape.
    '''
    
    self.NUM_CLASSES = num_classes
    self.INPUT_SHAPE = input_shape


  @staticmethod
  def euclidean_distance(input):
    '''
    Utility function to calculate the Euclidean distance.

    Args:
      input::[tuple]
      Input vectors.

    Returns:
      Euclidean distance between vectors.
    '''
    v1, v2 = input
    ss = K.sum(K.square(v1 - v2), axis=1, keepdims=True)
    return K.sqrt(K.maximum(ss, K.epsilon()))

  def bn(self, print_summary = False):
    '''
    Base Convolution Siamese Network. This architecture is under study.

    Args:
      print_summary::[bool]
      For development check model architecture.

    Returns:
      Base model.
    '''

    input = Input(shape = self.INPUT_SHAPE)
    x = Conv2D(4, (5,5), activation = 'tanh')(input)
    x = AveragePooling2D(pool_size = (2,2))(x)
    x = Conv2D(16, (5,5), activation = 'tanh')(x)
    x = AveragePooling2D(pool_size = (2,2))(x)
    x = Flatten()(x)
    x = Dense(128, activation = 'relu')(x)
    x = Lambda(lambda  x: K.l2_normalize(x,axis=1))(x)
    model = Model(input, x)
    
    if print_summary:
      model.summary()
    
    return model

  def bn1(self, print_summary = False):
    '''
    Base Fully Connected Siamese Network. Works well.

    Args:
      print_summary::[bool]
      For development check model architecture.

    Returns:
      Base model.
    '''
    input = Input(shape = self.INPUT_SHAPE)
    x = Flatten()(input)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.1)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.1)(x)
    x = Dense(128, activation='relu')(x)
    x = Lambda(lambda  x: K.l2_normalize(x,axis=1))(x)
    model = Model(input, x)
    
    if print_summary:
      model.summary()
    
    return model


  def __call__(self):
    '''
    Create model.
    '''
    # bn is under study
    # bnet = self.bn()

    # Working bn1 architecture. This is a fully connected network.
    bnet = self.bn1()

    # Two inputs.
    input_left = Input(shape=self.INPUT_SHAPE)
    input_right = Input(shape=self.INPUT_SHAPE)

    # Output of base networks.
    out_left = bnet(input_left)
    out_right = bnet(input_right)

    # Euclidean distance of 128 length output vectors.
    distance = Lambda(Siamese_Model.euclidean_distance,
                      output_shape=(1,1))([out_left, out_right])

    # Construct final model.
    model = Model([input_left, input_right], distance)

    return model

# %% [markdown]
# # Train the model

# %%
class TrainLoop():
  '''
  Training Process Handler.
  '''
  def __init__(self, epochs, batch_size, optimizer, tr_pairs, tr_y):
    '''
    Initialize the training params.

    Args:
      epochs::[int]
      The number of epochs to train the model.

      batch_size::[int]
      The number of images in a batch.

      optimizer::[object]
      Keras optimizer object.

      tr_pairs::[numpy.ndarray]
      Training Image Pairs.

      ty_y::[numpy.array]
      Training labels.
    '''
    self.EPOCHS = epochs
    self.OPTIMIZER = optimizer
    self.BATCH_SIZE = batch_size
    self.tr_pairs = tr_pairs
    self.tr_y = tr_y
    

  def __call__(self):
    '''
    Compile and train the model.
    '''

    # Initialize the model object.
    sm_obj = Siamese_Model()

    # Call the model.
    sm = sm_obj()

    # Compile the model.
    sm.compile(optimizer = self.OPTIMIZER, loss = CustomCL(), metrics = [custom_acc])

    print('Compiled model. Starting training process.')

    history = sm.fit([self.tr_pairs[:, 0], self.tr_pairs[:, 1]], self.tr_y,
          batch_size=self.BATCH_SIZE,
          epochs=self.EPOCHS, validation_split=0.1)
    
    print('Finished training.')
    
    return sm, history

# %%
# Train Model.
train_obj = TrainLoop(100, 128, RMSprop(), dp_output[0], dp_output[1])

# %%
result = train_obj()
# Out:
# Compiled model. Starting training process.
# Epoch 1/100
# 34/34 [==============================] - 5s 44ms/step - loss: 0.2601 - custom_acc: 0.4898 - val_loss: 0.3777 - val_custom_acc: 0.5000
# Epoch 2/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.2559 - custom_acc: 0.5135 - val_loss: 0.3742 - val_custom_acc: 0.5000
# Epoch 3/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.2593 - custom_acc: 0.4905 - val_loss: 0.3568 - val_custom_acc: 0.4961
# Epoch 4/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.2552 - custom_acc: 0.5103 - val_loss: 0.3263 - val_custom_acc: 0.4707
# Epoch 5/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.2541 - custom_acc: 0.5191 - val_loss: 0.3252 - val_custom_acc: 0.4538
# Epoch 6/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.2490 - custom_acc: 0.5554 - val_loss: 0.3111 - val_custom_acc: 0.4551
# Epoch 7/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.2310 - custom_acc: 0.6232 - val_loss: 0.2650 - val_custom_acc: 0.5703
# Epoch 8/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.2083 - custom_acc: 0.6848 - val_loss: 0.2913 - val_custom_acc: 0.5104
# Epoch 9/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1936 - custom_acc: 0.7129 - val_loss: 0.1813 - val_custom_acc: 0.7201
# Epoch 10/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1822 - custom_acc: 0.7334 - val_loss: 0.1387 - val_custom_acc: 0.8151
# Epoch 11/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1750 - custom_acc: 0.7536 - val_loss: 0.1206 - val_custom_acc: 0.8509
# Epoch 12/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1691 - custom_acc: 0.7637 - val_loss: 0.1472 - val_custom_acc: 0.8118
# Epoch 13/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.1590 - custom_acc: 0.7765 - val_loss: 0.1307 - val_custom_acc: 0.8249
# Epoch 14/100
# 34/34 [==============================] - 1s 36ms/step - loss: 0.1606 - custom_acc: 0.7748 - val_loss: 0.1233 - val_custom_acc: 0.8496
# Epoch 15/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.1564 - custom_acc: 0.7827 - val_loss: 0.1188 - val_custom_acc: 0.8496
# Epoch 16/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1526 - custom_acc: 0.7887 - val_loss: 0.1348 - val_custom_acc: 0.8053
# Epoch 17/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1553 - custom_acc: 0.7782 - val_loss: 0.1240 - val_custom_acc: 0.8477
# Epoch 18/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1456 - custom_acc: 0.7993 - val_loss: 0.2780 - val_custom_acc: 0.5775
# Epoch 19/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.1469 - custom_acc: 0.7960 - val_loss: 0.1950 - val_custom_acc: 0.7188
# Epoch 20/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1472 - custom_acc: 0.7933 - val_loss: 0.1194 - val_custom_acc: 0.8431
# Epoch 21/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.1382 - custom_acc: 0.8120 - val_loss: 0.1381 - val_custom_acc: 0.8040
# Epoch 22/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1360 - custom_acc: 0.8099 - val_loss: 0.1177 - val_custom_acc: 0.8451
# Epoch 23/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1396 - custom_acc: 0.8082 - val_loss: 0.1388 - val_custom_acc: 0.8301
# Epoch 24/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1348 - custom_acc: 0.8153 - val_loss: 0.1317 - val_custom_acc: 0.8327
# Epoch 25/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1356 - custom_acc: 0.8157 - val_loss: 0.1173 - val_custom_acc: 0.8509
# Epoch 26/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1319 - custom_acc: 0.8227 - val_loss: 0.1198 - val_custom_acc: 0.8359
# Epoch 27/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1306 - custom_acc: 0.8191 - val_loss: 0.1217 - val_custom_acc: 0.8099
# Epoch 28/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1285 - custom_acc: 0.8243 - val_loss: 0.0989 - val_custom_acc: 0.8822
# Epoch 29/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.1289 - custom_acc: 0.8255 - val_loss: 0.1781 - val_custom_acc: 0.7507
# Epoch 30/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.1271 - custom_acc: 0.8273 - val_loss: 0.0874 - val_custom_acc: 0.8932
# Epoch 31/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1230 - custom_acc: 0.8331 - val_loss: 0.1267 - val_custom_acc: 0.8359
# Epoch 32/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.1261 - custom_acc: 0.8300 - val_loss: 0.1047 - val_custom_acc: 0.8698
# Epoch 33/100
# 34/34 [==============================] - 1s 38ms/step - loss: 0.1262 - custom_acc: 0.8279 - val_loss: 0.0854 - val_custom_acc: 0.8939
# Epoch 34/100
# 34/34 [==============================] - 1s 42ms/step - loss: 0.1164 - custom_acc: 0.8416 - val_loss: 0.1069 - val_custom_acc: 0.8548
# Epoch 35/100
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1175 - custom_acc: 0.8444 - val_loss: 0.0879 - val_custom_acc: 0.8900
# Epoch 36/100
# 34/34 [==============================] - 2s 48ms/step - loss: 0.1191 - custom_acc: 0.8420 - val_loss: 0.0866 - val_custom_acc: 0.8880
# Epoch 37/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1172 - custom_acc: 0.8393 - val_loss: 0.1156 - val_custom_acc: 0.8587
# Epoch 38/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1148 - custom_acc: 0.8484 - val_loss: 0.0826 - val_custom_acc: 0.9010
# Epoch 39/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1133 - custom_acc: 0.8479 - val_loss: 0.1207 - val_custom_acc: 0.8197
# Epoch 40/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1111 - custom_acc: 0.8522 - val_loss: 0.0877 - val_custom_acc: 0.8952
# Epoch 41/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.1079 - custom_acc: 0.8613 - val_loss: 0.1439 - val_custom_acc: 0.8073
# Epoch 42/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1045 - custom_acc: 0.8671 - val_loss: 0.0852 - val_custom_acc: 0.8971
# Epoch 43/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1124 - custom_acc: 0.8448 - val_loss: 0.0908 - val_custom_acc: 0.8835
# Epoch 44/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1107 - custom_acc: 0.8551 - val_loss: 0.0797 - val_custom_acc: 0.9043
# Epoch 45/100
# 34/34 [==============================] - 1s 39ms/step - loss: 0.1062 - custom_acc: 0.8579 - val_loss: 0.1051 - val_custom_acc: 0.8802
# Epoch 46/100
# 34/34 [==============================] - 1s 42ms/step - loss: 0.1096 - custom_acc: 0.8526 - val_loss: 0.0782 - val_custom_acc: 0.9089
# Epoch 47/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.1023 - custom_acc: 0.8663 - val_loss: 0.1028 - val_custom_acc: 0.8796
# Epoch 48/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.1008 - custom_acc: 0.8703 - val_loss: 0.1048 - val_custom_acc: 0.8613
# Epoch 49/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.1062 - custom_acc: 0.8583 - val_loss: 0.0949 - val_custom_acc: 0.8913
# Epoch 50/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.1047 - custom_acc: 0.8603 - val_loss: 0.1883 - val_custom_acc: 0.7526
# Epoch 51/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0961 - custom_acc: 0.8738 - val_loss: 0.0800 - val_custom_acc: 0.9089
# Epoch 52/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1037 - custom_acc: 0.8622 - val_loss: 0.1061 - val_custom_acc: 0.8620
# Epoch 53/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.1069 - custom_acc: 0.8517 - val_loss: 0.0904 - val_custom_acc: 0.8958
# Epoch 54/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0939 - custom_acc: 0.8768 - val_loss: 0.2505 - val_custom_acc: 0.6621
# Epoch 55/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0981 - custom_acc: 0.8691 - val_loss: 0.1190 - val_custom_acc: 0.8522
# Epoch 56/100
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0935 - custom_acc: 0.8762 - val_loss: 0.0959 - val_custom_acc: 0.8900
# Epoch 57/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.1000 - custom_acc: 0.8660 - val_loss: 0.1298 - val_custom_acc: 0.8411
# Epoch 58/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0955 - custom_acc: 0.8761 - val_loss: 0.0807 - val_custom_acc: 0.9017
# Epoch 59/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0932 - custom_acc: 0.8806 - val_loss: 0.0807 - val_custom_acc: 0.8997
# Epoch 60/100
# 34/34 [==============================] - 1s 38ms/step - loss: 0.0944 - custom_acc: 0.8756 - val_loss: 0.1001 - val_custom_acc: 0.8854
# Epoch 61/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0913 - custom_acc: 0.8792 - val_loss: 0.0970 - val_custom_acc: 0.8776
# Epoch 62/100
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0910 - custom_acc: 0.8802 - val_loss: 0.0928 - val_custom_acc: 0.8711
# Epoch 63/100
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0924 - custom_acc: 0.8781 - val_loss: 0.0802 - val_custom_acc: 0.8952
# Epoch 64/100
# 34/34 [==============================] - 1s 42ms/step - loss: 0.0878 - custom_acc: 0.8843 - val_loss: 0.0976 - val_custom_acc: 0.8815
# Epoch 65/100
# 34/34 [==============================] - 1s 35ms/step - loss: 0.0897 - custom_acc: 0.8840 - val_loss: 0.1711 - val_custom_acc: 0.7702
# Epoch 66/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0924 - custom_acc: 0.8780 - val_loss: 0.0799 - val_custom_acc: 0.9082
# Epoch 67/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0880 - custom_acc: 0.8850 - val_loss: 0.0824 - val_custom_acc: 0.8926
# Epoch 68/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0881 - custom_acc: 0.8858 - val_loss: 0.0875 - val_custom_acc: 0.8854
# Epoch 69/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0892 - custom_acc: 0.8793 - val_loss: 0.0844 - val_custom_acc: 0.8861
# Epoch 70/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0799 - custom_acc: 0.8966 - val_loss: 0.0898 - val_custom_acc: 0.8926
# Epoch 71/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0853 - custom_acc: 0.8880 - val_loss: 0.0918 - val_custom_acc: 0.8757
# Epoch 72/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0814 - custom_acc: 0.8978 - val_loss: 0.0959 - val_custom_acc: 0.8828
# Epoch 73/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0814 - custom_acc: 0.8912 - val_loss: 0.0774 - val_custom_acc: 0.9017
# Epoch 74/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0810 - custom_acc: 0.8931 - val_loss: 0.0834 - val_custom_acc: 0.9017
# Epoch 75/100
# 34/34 [==============================] - 1s 35ms/step - loss: 0.0788 - custom_acc: 0.8984 - val_loss: 0.1594 - val_custom_acc: 0.7871
# Epoch 76/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0822 - custom_acc: 0.8922 - val_loss: 0.1274 - val_custom_acc: 0.8132
# Epoch 77/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0819 - custom_acc: 0.8911 - val_loss: 0.0897 - val_custom_acc: 0.8919
# Epoch 78/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0754 - custom_acc: 0.9023 - val_loss: 0.1241 - val_custom_acc: 0.8411
# Epoch 79/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0819 - custom_acc: 0.8920 - val_loss: 0.1042 - val_custom_acc: 0.8685
# Epoch 80/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0767 - custom_acc: 0.8988 - val_loss: 0.1041 - val_custom_acc: 0.8665
# Epoch 81/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0758 - custom_acc: 0.9036 - val_loss: 0.2259 - val_custom_acc: 0.6816
# Epoch 82/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0733 - custom_acc: 0.9039 - val_loss: 0.0973 - val_custom_acc: 0.8770
# Epoch 83/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0755 - custom_acc: 0.9000 - val_loss: 0.1128 - val_custom_acc: 0.8672
# Epoch 84/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0758 - custom_acc: 0.9018 - val_loss: 0.1290 - val_custom_acc: 0.8379
# Epoch 85/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0715 - custom_acc: 0.9070 - val_loss: 0.0830 - val_custom_acc: 0.8919
# Epoch 86/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0775 - custom_acc: 0.8976 - val_loss: 0.1161 - val_custom_acc: 0.8431
# Epoch 87/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0717 - custom_acc: 0.9102 - val_loss: 0.0726 - val_custom_acc: 0.9076
# Epoch 88/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0780 - custom_acc: 0.8984 - val_loss: 0.0643 - val_custom_acc: 0.9199
# Epoch 89/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0731 - custom_acc: 0.9084 - val_loss: 0.0744 - val_custom_acc: 0.9056
# Epoch 90/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0691 - custom_acc: 0.9115 - val_loss: 0.0699 - val_custom_acc: 0.9069
# Epoch 91/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0754 - custom_acc: 0.8999 - val_loss: 0.1085 - val_custom_acc: 0.8411
# Epoch 92/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0763 - custom_acc: 0.8983 - val_loss: 0.0627 - val_custom_acc: 0.9271
# Epoch 93/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0705 - custom_acc: 0.9090 - val_loss: 0.0834 - val_custom_acc: 0.8913
# Epoch 94/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0671 - custom_acc: 0.9167 - val_loss: 0.0710 - val_custom_acc: 0.9121
# Epoch 95/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0689 - custom_acc: 0.9128 - val_loss: 0.1226 - val_custom_acc: 0.8346
# Epoch 96/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0697 - custom_acc: 0.9099 - val_loss: 0.0896 - val_custom_acc: 0.8789
# Epoch 97/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0708 - custom_acc: 0.9117 - val_loss: 0.0779 - val_custom_acc: 0.9023
# Epoch 98/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0654 - custom_acc: 0.9142 - val_loss: 0.0851 - val_custom_acc: 0.8887
# Epoch 99/100
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0697 - custom_acc: 0.9102 - val_loss: 0.1187 - val_custom_acc: 0.8490
# Epoch 100/100
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0694 - custom_acc: 0.9079 - val_loss: 0.0837 - val_custom_acc: 0.8984
# Finished training.

# %%
# %whos
# Out:
# Variable           Type         Data/Info
# -----------------------------------------
# Activation         type         <class 'keras.layers.core.activation.Activation'>
# AveragePooling2D   type         <class 'keras.layers.pooling.AveragePooling2D'>
# Conv2D             type         <class 'keras.layers.convolutional.Conv2D'>
# CustomCL           type         <class '__main__.CustomCL'>
# Dense              type         <class 'keras.layers.core.dense.Dense'>
# Dropout            type         <class 'keras.layers.core.dropout.Dropout'>
# Flatten            type         <class 'keras.layers.core.flatten.Flatten'>
# Image              module       <module 'PIL.Image' from <...>t-packages/PIL/Image.py'>
# Input              function     <function Input at 0x7f266b406440>
# K                  module       <module 'keras.api._v2.ke<...>ras/backend/__init__.py'>
# Lambda             type         <class 'keras.layers.core.lambda_layer.Lambda'>
# Model              type         <class 'keras.engine.training.Model'>
# RMSprop            type         <class 'keras.optimizer_v2.rmsprop.RMSprop'>
# Siamese_Model      type         <class '__main__.Siamese_Model'>
# TrainLoop          type         <class '__main__.TrainLoop'>
# compute_acc        function     <function compute_acc at 0x7f266a07b320>
# custom_acc         function     <function custom_acc at 0x7f266a07b0e0>
# dp_output          tuple        n=2
# keras              module       <module 'tensorflow.keras<...>i/_v2/keras/__init__.py'>
# np                 module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# os                 module       <module 'os' from '/usr/lib/python3.7/os.py'>
# random             module       <module 'random' from '/u<...>lib/python3.7/random.py'>
# result             tuple        n=2
# tf                 module       <module 'tensorflow' from<...>/tensorflow/__init__.py'>
# tqdm               type         <class 'tqdm.std.tqdm'>
# train_obj          TrainLoop    <__main__.TrainLoop object at 0x7f266a032250>

# %% [markdown]
# Leaky memory problem. Predict function execution causes RAM to increase beyond capacity causing session to crash. https://github.com/keras-team/keras/issues/13118

# %% [markdown]
# ### Possible solution is to convert numpy to tensor and pass to model

# %%
input_tensor0 = tf.convert_to_tensor(dp_output[0][:,0])
input_tensor1 = tf.convert_to_tensor(dp_output[0][:,1])

# %%
output_tensor = result[0]([input_tensor0, input_tensor1])

# %%
y_tr_pred = output_tensor.numpy()

# %%
print(f'Computed prediction on training set. {y_tr_pred.shape}')
# Out:
# Computed prediction on training set. (4796, 1)

# %%
training_accuracy = compute_acc(dp_output[1], y_tr_pred)

# %%
# Training accuracy.
print('Accuracy on training set: %0.2f%%' % (100 * training_accuracy))
# Out:
# Accuracy on training set: 94.08%

# %%
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(dp_output[1], y_tr_pred < 0.5)

print(cf_matrix)
# Out:
# [[2276  122]
#  [ 162 2236]]

# %%
import seaborn as sns

ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues', fmt='g')

ax.set_title('Confusion Matrix for Training set\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Not Same','Same'])
ax.yaxis.set_ticklabels(['Not Same','Same'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# # Prediction result.

# %%
K.clear_session()
# from numba import cuda
# cuda.select_device(0)
# cuda.close()

# %%
# Predict Training samples with trained model.
# y_tr_pred = result[0].predict([dp_output[0][:,0], dp_output[0][:,1]])

# %%
# Prediction shape.
# print(f'Computed prediction on training set. {y_tr_pred.shape}')

# %%
# Training final accuracy
# training_accuracy = compute_acc(dp_output[1], y_tr_pred)

# %%
# Training accuracy.
# print('Accuracy on training set: %0.2f%%' % (100 * training_accuracy))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(result[1].history['custom_acc'])
plt.plot(result[1].history['val_custom_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','val'], loc='upper left')
plt.show()
# summarize history for loss

plt.plot(result[1].history['loss'])
plt.plot(result[1].history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','val'], loc='upper left')
plt.show()

# %% [markdown]
# # To-Do
# - Create prediction on test set.
# - Demo original use case of classifying a directory to extract background images, from mantaray images.
# - Use the trained model output vector to perform clustering. This will form basis to cluster different mantaray images, and to understand the unique feature of these fish.

# %% [markdown]
# # Reference
# - https://medium.com/@maksym.bekuzarov/losses-explained-contrastive-loss-f8f57fe32246

# %% [markdown]
# ## Extended data preparation

# %%
# import os
# len(os.listdir('/content/drive/MyDrive/data_folder/train2020'))
# Out:
# 2839

# %%
# from random import sample
# bl = sample(os.listdir('/content/drive/MyDrive/data_folder/bottom_left'), 100)
# br = sample(os.listdir('/content/drive/MyDrive/data_folder/bottom_right'), 100)
# tl = sample(os.listdir('/content/drive/MyDrive/data_folder/top_left'), 100)
# tr = sample(os.listdir('/content/drive/MyDrive/data_folder/top_right'), 100)

# %%
# import os, shutil
# path = "/content/drive/MyDrive/data_folder/train2020"
# moveto = "/content/drive/MyDrive/data_folder/test"
# for f in bl:
#     src = os.path.join(path,f)
#     dst = os.path.join(moveto, 'manta_'+f)
#     shutil.move(src,dst)

# %%
# import os
# test_image_list = os.listdir('/content/drive/MyDrive/data_folder/test')

# %%
# import pandas as pd
# test_label = pd.Series(test_image_list).apply(lambda x: 0 if 'back' in x else 1)

# %%
# test_image_list = [os.path.join('/content/drive/MyDrive/data_folder/test',i) for i in test_image_list]

# %%
# test_csv = pd.DataFrame({'test_image_path': test_image_list, 'test_label': test_label})

# %%
# test_csv.tail()
# Out:
#                                        test_image_path  test_label
# 795  /content/drive/MyDrive/data_folder/test/back_0...           0
# 796  /content/drive/MyDrive/data_folder/test/back_0...           0
# 797  /content/drive/MyDrive/data_folder/test/back_0...           0
# 798  /content/drive/MyDrive/data_folder/test/back_0...           0
# 799  /content/drive/MyDrive/data_folder/test/back_0...           0

# %%
# Here 0 is mantaray images and 1 is no fish or just background.

# %%
# test_csv.to_csv('/content/drive/MyDrive/data_folder/test_info.csv')

# %%
# import pandas as pd
# import numpy as np
# from tqdm import tqdm
# tqdm.pandas()

# %%
# Let's create test pairs
# First read in the images into an array
# X_test = test_csv.test_image_path.progress_apply(lambda x: np.asarray(Image.open(x).resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS)))
# Out:
# 100%|██████████| 800/800 [07:45<00:00,  1.72it/s]

# %%
# X_test = np.concatenate(X_test).reshape(X_test.shape[0],128,128,3)

# %%
# X_test = X_test / 255

# %%
# y_test = np.array(test_csv['test_label'])

# %%
# assert len(X_test) == len(y_test)

# %%
# p = np.random.default_rng(77).permutation(len(X_test))

# %%
# X_test, y_test = X_test[p], y_test[p]

# %%
# num_classes = len(np.unique(y_test))

# %%
# num_classes
# Out:
# 2

# %%
# digit_indices = [np.where(y_test == i)[0] for i in range(num_classes)]

# %%
# def create_pairs(x, class_indices):
#     '''
#     Function that creates Siamese network input pairs and labels. Here the 
#     objective is to create matching pairs marked as label 1 and non-matching 
#     pairs marked as label 0.

#     Args:
#       x::[np.array]
#       The image numpy array data.
      
#       class_indices::[np.array]
#       An array containing an array for each category, indicating the image
#       position within array.

#     Returns:
#       Pairs and labels.
#     '''

#     print('Started creating pairs ...')

#     # Pairs
#     pairs = []
    
#     # Labels. If same class image then 1, or else 0.
#     labels = []

#     # Since, each category has variable images, take the minimum to avoid
#     # list range problem.
#     n = min( [len(class_indices[c]) for c in range(num_classes)] ) - 1

#     # For each class
#     for d in range(num_classes):

#       # For each sample
#       for i in range(n):

#         # Form pairs with current and next image in same class.
#         i1, i2 = class_indices[d][i], class_indices[d][i+1]
        
#         # Add this image pair to training set.
#         pairs += [[x[i1], x[i2]]]
        
#         # Randomly add a number from 1 to num_class to current class.
#         # Shift the base as class starts with 0.
#         inc = random.randrange(1, num_classes)
#         dn = (d + inc) % num_classes

#         # Add training pair from different classes.
#         # That is our class 0.
#         i1, i2 = class_indices[d][i], class_indices[dn][i]
#         pairs += [[x[i1], x[i2]]]

#         # Add labels
#         labels += [1,0]

#     print('Finished creating pairs & labels. :)')
        
#     return np.array(pairs), np.array(labels)

# %%
# x_output = create_pairs(X_test, digit_indices)
# Out:
# Started creating pairs ...
# Finished creating pairs & labels. :)

# %%
# x_output[0][:,0].shape
# Out:
# (1596, 128, 128, 3)

# %%
# x_output[1]
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
# np.save('x_test_array.npy', x_output[0])

# %%
# np.save('/content/drive/MyDrive/data_folder/x_test_label.npy', x_output[1])

# %% [markdown]
# ### Testing on test set

# %%
import numpy as np
with open('/content/drive/MyDrive/data_folder/x_test_array.npy', 'rb') as f:
  x_test_array = np.load(f)

# %%
with open('/content/drive/MyDrive/data_folder/x_test_label.npy', 'rb') as f:
  x_test_label = np.load(f)

# %%
x_test_tensor0 = tf.convert_to_tensor(x_test_array[:,0])
x_test_tensor1 = tf.convert_to_tensor(x_test_array[:,1])

# %%
y_test_pred = result[0]([x_test_tensor0, x_test_tensor1])

# %%
print(f'Computed prediction on training set. {y_test_pred.shape}')
# Out:
# Computed prediction on training set. (1596, 1)

# %%
test_accuracy = compute_acc(x_test_label, y_test_pred.numpy())

# %%
print('Accuracy on training set: %0.2f%%' % (100 * test_accuracy))
# Out:
# Accuracy on training set: 79.32%

# %%
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(x_test_label, y_test_pred < 0.5)

print(cf_matrix)
# Out:
# [[634 164]
#  [166 632]]

# %%
import seaborn as sns

ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues', fmt='g')

ax.set_title('Confusion Matrix for Test set\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Not Same','Same'])
ax.yaxis.set_ticklabels(['Not Same','Same'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ### Now, let us try to use an anchor image (one background image) and find similar images in our directory. These images are random images, from other dataset and a few from the given test set. We have not at all trained on these images, so it is interesting to see the performance on outside of the training set.

# %%
#let the anchor be
anchor = 'back_br_000000005110'
main_dir = '/content/drive/MyDrive/data_folder/processed_val_1000_back_manta'
IMAGE_SIZE = 128
# Read in all images except anchor into array.
image_set = os.listdir(main_dir)
image_list = []

for i in tqdm(image_set):
  fp = os.path.join(main_dir, i)

  if anchor not in i:
    image_list.append(np.asarray(Image.open(fp).resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS)))
# Out:
# 100%|██████████| 1000/1000 [00:43<00:00, 23.19it/s]

# %%
test_image_set = np.array(image_list)

# %%
test_image_set.shape
# Out:
# (999, 128, 128, 3)

# %%
# Read in anchor
anchor1 = anchor + '.jpg' 
anchor_image1 = np.asarray(Image.open(os.path.join(main_dir, anchor1)).resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS))

# %%
anchor_image1.shape
# Out:
# (128, 128, 3)

# %%
anchor_image = np.tile(np.expand_dims(anchor_image1,axis=0),(999,1,1,1))

# %%
x_test_tensor0 = tf.convert_to_tensor(test_image_set)
x_test_tensor1 = tf.convert_to_tensor(anchor_image)

# %%
y_anchor_pred = result[0]([x_test_tensor0, x_test_tensor1])

# %%
y_anchor_pred_np = y_anchor_pred.numpy()

# %%
res = tf.math.top_k(
    y_anchor_pred_np.reshape(-1,), k=5, sorted=True, name=None
)

# %%
v = res.values.numpy()

# %%
i = res.indices.numpy()

# %%
# Top - 5 prediction result
# Code Creates a grid
_, axes_grid = plt.subplots(1, 6, figsize = (3*6, 3*1))

it = 0
it1 = 0
for ax in axes_grid:

  if it == 0:
    
    ax.imshow(anchor_image1)
    ax.set_title('Anchor image')
    it += 1
    continue
  

  ax.imshow(test_image_set[i[it1]])
  ax.set_title(f'Similarity score: {v[it1]:.2f}')
  it1 += 1

# %% [markdown]
# Gives, good results on an empty background images. Let us try a mantaray.

# %%
#let the anchor be
anchor = 'manta_000000001465'
main_dir = '/content/drive/MyDrive/data_folder/processed_val_1000_back_manta'
IMAGE_SIZE = 128
# Read in all images except anchor into array.
image_set = os.listdir(main_dir)
image_list = []

for i in tqdm(image_set):
  fp = os.path.join(main_dir, i)

  if anchor not in i:
    image_list.append(np.asarray(Image.open(fp).resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS)))
# Out:
# 100%|██████████| 1000/1000 [00:34<00:00, 28.78it/s]

# %%
test_image_set = np.array(image_list)
test_image_set.shape
# Out:
# (999, 128, 128, 3)

# %%
# Read in anchor
anchor1 = anchor + '.jpg' 
anchor_image1 = np.asarray(Image.open(os.path.join(main_dir, anchor1)).resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS))

# %%
anchor_image1.shape
# Out:
# (128, 128, 3)

# %%
anchor_image = np.tile(np.expand_dims(anchor_image1,axis=0),(999,1,1,1))

# %%
x_test_tensor0 = tf.convert_to_tensor(test_image_set)
x_test_tensor1 = tf.convert_to_tensor(anchor_image)

# %%
y_anchor_pred = result[0]([x_test_tensor0, x_test_tensor1])

# %%
y_anchor_pred_np = y_anchor_pred.numpy()

# %%
res = tf.math.top_k(
    y_anchor_pred_np.reshape(-1,), k=5, sorted=True, name=None
)
v = res.values.numpy()
i = res.indices.numpy()

# %%
# Top - 5 prediction result
# Code Creates a grid
_, axes_grid = plt.subplots(1, 6, figsize = (3*6, 3*1))

it = 0
it1 = 0
for ax in axes_grid:

  if it == 0:
    
    ax.imshow(anchor_image1)
    ax.set_title('Anchor image')
    it += 1
    continue
  

  ax.imshow(test_image_set[i[it1]])
  ax.set_title(f'Similarity score: {v[it1]:.2f}')
  it1 += 1

# %% [markdown]
# It seems the model is not doing well when given a mantaray image. We need to train the model for more number of epochs, or we can continue to study better methods to perform clustering.

# %% [markdown]
# - If we have time try to use TSNE to visualize the embeddings. Check Tenp notion for more details.
